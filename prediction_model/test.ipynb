# %%
import numpy as np
import pandas as pd

data = pd.read_csv('dataset.csv');

data.head()
# Out:
#    Id  Age  Grade  StudyTime OnlineCourse   SchoolType ClassType  SelfStudy  \
# 0   1   18     13          3           no  specialized    normal          5
# 1   2   18     11          1           no       public    gifted          4
# 2   3   16     13          4          yes       public    gifted          1
# 3   4   16     10          1           no  specialized    normal          2
# 4   5   16     13          1           no      private    gifted          2
#
#    GoingOut  Health  ...  AverageExerciseScore  TestsCompleted  \
# 0         4       5  ...                  1.79              34
# 1         2       5  ...                  8.97               9
# 2         5       3  ...                  6.10              48
# 3         1       5  ...                  7.67              20
# 4         5       4  ...                  8.72              46
#
#    AverageTestScore  AverageTestCompletionTime  ArenaParticipation  \
# ...

# %%
import matplotlib.pyplot as plt

plt.scatter(data['AverageExerciseScore'], data['PredictScore'], alpha=0.5)
plt.title('Scatter Plot giữa AverageTestScore và WebScore')
plt.xlabel('AverageTestScore')
plt.ylabel('WebScore')
plt.grid(True)
plt.show()
